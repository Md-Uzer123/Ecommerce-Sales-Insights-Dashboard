# %%
import kaggle

# %%
# !kaggle datasets download anshika2301/vrinda-store-data-analysis -f "Store Data.xlsx"
path = !kaggle datasets download anshika2301/vrinda-store-data-analysis -f "Store Data.xlsx"
# import kagglehub

# Download latest version
# path = kagglehub.dataset_download("anshika2301/vrinda-store-data-analysis")

print("Path to dataset files:", path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anshika2301/vrinda-store-data-analysis
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/3.60M [00:00<?, ?B/s]
#  28%|##7       | 1.00M/3.60M [00:01<00:04, 648kB/s]
#  56%|#####5    | 2.00M/3.60M [00:01<00:01, 1.22MB/s]
#  83%|########3 | 3.00M/3.60M [00:02<00:00, 2.01MB/s]
# 100%|##########| 3.60M/3.60M [00:02<00:00, 2.33MB/s]
# 100%|##########| 3.60M/3.60M [00:02<00:00, 1.69MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 8
#       4
#       5 # Download latest version
#       6 # path = kagglehub.dataset_download("anshika2301/vrinda-store-data-analysis")
#       7
# ----> 8 print("Path to dataset files:", path)
#
# NameError: name 'path' is not defined

# %%
#extract file from zip file
import zipfile
zip_ref = zipfile.ZipFile('Store%20Data.xlsx.zip')
zip_ref.extractall()
zip_ref.close()

# %%
#read data from the file and handle null values
import pandas as pd
# df = pd.read_excel('Store Data.xlsx')
df = pd.read_excel('Vrinda Store Data Analysis.xlsx')
df.head(20)
# Out:
#     index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0       1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1       2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2       3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3       4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4       5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# 5       6  407-1298130-0368305  1298130    Men   49 2022-12-04  Delivered
# 6       7  407-1298130-0368305  1298130  Women   23 2022-12-04  Delivered
# 7       8  171-5561216-3398711  5561216  Women   70 2022-12-04  Delivered
# 8       9  408-2935263-2935550  2935263  Women   75 2022-12-04  Delivered
# 9      10  404-2648970-9042715  2648970  Women   43 2022-12-04  Delivered
# 10     11  404-2648970-9042715  2648970  Women   76 2022-12-04  Delivered
# 11     12  404-2648970-9042715  2648970  Women   45 2022-12-04  Delivered
# ...

# %%
# Shape (Rows, Columns)
# print("Shape:", df.shape)

# Data types aur null values
print(df.info())

# Pehli 5 rows
# df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  str
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  str
#  4   Age               31047 non-null  int64
#  5   Date              31047 non-null  datetime64[us]
#  6   Status            31047 non-null  str
#  7   Channel           31047 non-null  str
#  8   SKU               31047 non-null  str
#  9   Category          31047 non-null  str
#  10  Size              31047 non-null  str
#  11  Qty               31047 non-null  int64
#  12  currency          31047 non-null  str
#  13  Amount            31047 non-null  int64
#  14  ship-city         31047 non-null  str
#  15  ship-state        31047 non-null  str
#  16  ship-postal-code  31047 non-null  int64
# ...

# %%
# Check karo kahan-kahan null hai
print(df.isnull().sum())
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Date                0
# Status              0
# Channel             0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
# Check duplicates
print("Duplicates:", df.duplicated().sum())

# Agar hain toh drop karo
 df = df.drop_duplicates()
# Out:
# Duplicates: 0

# %%
df
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097    Men   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097    Men   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295    Men   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498    Men   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875    Men   36 2022-01-06  Delivered
#
# ...

# %%
# Modify Columns
# df.columns = df.columns.str.replace('-', '_')
df = df.rename(columns={'Channel_': 'Channel'})
df.columns
# Out:
# Index(['index', 'Order_ID', 'Cust_ID', 'Gender', 'Age', 'Date', 'Status',
#        'Channel', 'SKU', 'Category', 'Size', 'Qty', 'currency', 'Amount',
#        'ship_city', 'ship_state', 'ship_postal_code', 'ship_country', 'B2B'],
#       dtype='str')

# %%
# df.columns
df.info
# Out:
# <bound method DataFrame.info of        index             Order_ID  Cust_ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097    Men   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097    Men   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295    Men   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498    Men   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875    Men   36 2022-01-06  Delivered
#
# ...

# %%
df
# Out:
#        index             Order_ID  Cust_ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097    Men   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097    Men   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295    Men   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498    Men   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875    Men   36 2022-01-06  Delivered
#
# ...

# %%
df.info
df.head()
# Out:
#    index             Order_ID  Cust_ID Gender  Age       Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
#
#   Channel_                      SKU Category Size  Qty currency  Amount  \
# 0   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL    1      INR     376
# 1     Ajio           SET414-KR-NP-L      Set    L    1      INR    1449
# 2   Myntra           SET261-KR-PP-S      Set    S    1      INR     453
# 3   Amazon           SET110-KR-PP-M      Set    M    1      INR     729
# 4   Myntra         JNE2294-KR-A-XXL    kurta  XXL    1      INR     544
#
#    ship-city   ship-state  ship-postal-code ship-country    B2B
# ...

# %%
# df.head(5)
print(df.info())
# df.columns = df.columns.str.lower()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_index       31047 non-null  int64
#  1   order_id          31047 non-null  str
#  2   cust_id           31047 non-null  int64
#  3   gender            31047 non-null  str
#  4   age               31047 non-null  int64
#  5   date              31047 non-null  datetime64[us]
#  6   status            31047 non-null  str
#  7   channel           31047 non-null  str
#  8   sku               31047 non-null  str
#  9   category          31047 non-null  str
#  10  size              31047 non-null  str
#  11  qty               31047 non-null  int64
#  12  currency          31047 non-null  str
#  13  amount            31047 non-null  int64
#  14  ship_city         31047 non-null  str
#  15  ship_state        31047 non-null  str
#  16  ship_postal_code  31047 non-null  int64
# ...

# %%
# Column rename karo
# df = df.rename(columns={'index': 'Order_index'})
df.dtypes
# df.head(5)
# Out:
# order_index                  int64
# order_id                       str
# cust_id                      int64
# gender                         str
# age                          int64
# date                datetime64[us]
# status                         str
# channel                        str
# sku                            str
# category                       str
# size                           str
# qty                          int64
# currency                       str
# amount                       int64
# ship_city                      str
# ship_state                     str
# ship_postal_code             int64
# ship_country                   str
# b2b                           bool
# dtype: object

# %%
df
# Out:
#        order_index             order_id  cust_id gender  age       date  \
# 0                1  171-1029312-3038738  1029312  Women   44 2022-12-04
# 1                2  405-2183842-2225946  2183842  Women   29 2022-12-04
# 2                3  171-1641533-8921966  1641533  Women   67 2022-12-04
# 3                4  404-7490807-6300351  7490807  Women   20 2022-12-04
# 4                5  403-9293516-4577154  9293516  Women   62 2022-12-04
# ...            ...                  ...      ...    ...  ...        ...
# 31042        31043  405-4724097-1016369  4724097    Men   60 2022-01-06
# 31043        31044  405-4724097-1016369  4724097    Men   34 2022-01-06
# 31044        31045  408-3572295-5992330  3572295    Men   29 2022-01-06
# 31045        31046  405-1423498-9705162  1423498    Men   46 2022-01-06
# 31046        31047  408-4694875-8249153  4694875    Men   36 2022-01-06
#
#           status   channel                      sku       category size  qty  \
# ...

# %%
# 'index=False' lagana zaroori hai warna Pandas apna row number bhi save kar dega
# df.to_csv('cleaned_vrinda_store_data.csv', index=False)
# print("File saved successfully!")


df.to_excel('cleaned_vrinda_store_data.xlsx', index=False)
print("Excel file saved successfully!")
# Out:
# Excel file saved successfully!

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
# engine = sal.create_engine('mssql://MUZER\MSSQLSERVER01/OnlineBookStore?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
# engine = sal.create_engine('mssql+pyodbc://sa:Abc%40123@MUZER%5CMSSQLSERVER01/OnlineBookStore?driver=ODBC+Driver+17+for+SQL+Server')
engine = sal.create_engine(
    "mssql+pyodbc://sa:Abc%40123@MUZER\\MSSQLSERVER01/OnlineBookStore?driver=ODBC+Driver+17+for+SQL+Server"
)
conn=engine.connect()

# %%
#load the data into sql server using append option
df.to_sql('Stores', con=conn , index=False, if_exists = 'append')
# Out:
# 27
